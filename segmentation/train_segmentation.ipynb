# %%
from ultralytics import YOLO

# %% [markdown]
# ## How to calculate metrics

# %%
# Upload YOLOv8 weights (last)
model = YOLO('/home/martinson/runs/segment/seg; train s; small_data; no_aug _tune mech3/weights/last.pt')

# Set params
params = {
    "conf":0.1,
    "iou":0.1
}

# Evaluate results on valation and test 
results_val = model.val(**params)
results_test = model.val(split='test', **params)

# Upload YOLOv8 weights (best)
model = YOLO('/home/martinson/runs/segment/seg; train s; small_data; no_aug _tune mech3/weights/best.pt')

# Evaluate results on valation and test 
results_val_2 = model.val(**params)
results_test_2 = model.val(split='test', **params)
# Out:
# Ultralytics YOLOv8.0.128 🚀 Python-3.10.6 torch-2.0.1+cu117 CUDA:0 (NVIDIA A10G, 22564MiB)
# YOLOv8s-seg summary (fused): 195 layers, 11780374 parameters, 0 gradients, 42.4 GFLOPs
# val: Scanning /home/martinson/data_seg/labels.cache... 42 images, 0 backgrounds, 0 corrupt: 100%|██████████| 42/42 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:07<00:00,  2.34s/it]
#                    all         42       1324        0.6      0.179      0.099     0.0335      0.579      0.136     0.0665     0.0149
#                 BLURRY         42        982          1          0     0.0497     0.0162          1          0     0.0428     0.0112
#                SHARP_0         42        342      0.201      0.357      0.148     0.0508      0.159      0.272     0.0902     0.0185
# Speed: 2.5ms preprocess, 3.1ms inference, 0.0ms loss, 3.7ms postprocess per image
# ...

# %% [markdown]
# ## Results for different models (YOLOv8)

# %%
# 8
# seg; train s; small_data; no_aug _tune mech
# conf = 0.1
# iou = 0.1

print("Best")
print("Val (sharp precision):", results_val_2.box.p[1])
print("Test (sharp precision):", results_test_2.box.p[1])

print("Last")
print("Val (sharp precision):", results_val.box.p[1])
print("Test (sharp precision):", results_test.box.p[1])
# Out:
# Best
# Val (sharp precision): 0.47477064220183485
# Test (sharp precision): 0.43028846153846156
# Last
# Val (sharp precision): 0.4775241053215874
# Test (sharp precision): 0.40855367205793386

# %%
# 8
# seg; train s; small_data; no_aug _tune
# conf = 0.1
# iou = 0.1

print("Best")
print("Val (sharp precision):", results_val_2.box.p[1])
print("Test (sharp precision):", results_test_2.box.p[1])

print("Last")
print("Val (sharp precision):", results_val.box.p[1])
print("Test (sharp precision):", results_test.box.p[1])
# Out:
# Best
# Val (sharp precision): 0.4291136628540643
# Test (sharp precision): 0.4521863249720878
# Last
# Val (sharp precision): 0.416808784084749
# Test (sharp precision): 0.4280072803866267

# %%
# 8
# seg; train s; big_data; default _tune mech
# conf = 0.1
# iou = 0.1

print("Best")
print("Val (sharp precision):", results_val_2.box.p[1])
print("Test (sharp precision):", results_test_2.box.p[1])

print("Last")
print("Val (sharp precision):", results_val.box.p[1])
print("Test (sharp precision):", results_test.box.p[1])
# Out:
# Best
# Val (sharp precision): 0.4746345176447271
# Test (sharp precision): 0.40046296296296297
# Last
# Val (sharp precision): 0.5192982467778089
# Test (sharp precision): 0.39433551198257083

# %%
# 8
#seg; train s; big_data; mech_aug _tune2
# conf = 0.1
# iou = 0.1

print("Best")
print("Val (sharp precision):", results_val_2.box.p[1])
print("Test (sharp precision):", results_test_2.box.p[1])

print("Last")
print("Val (sharp precision):", results_val.box.p[1])
print("Test (sharp precision):", results_test.box.p[1])
# Out:
# Best
# Val (sharp precision): 0.499035951539502
# Test (sharp precision): 0.44054620892757573
# Last
# Val (sharp precision): 0.4888670777101272
# Test (sharp precision): 0.42547944113933567

# %%
# 8
# seg; train s; no_aug; full
# conf:0.1

print("Best")
print("Val (sharp precision):", results_val_2.box.p[1])
print("Test (sharp precision):", results_test_2.box.p[1])

print("Last")
print("Val (sharp precision):", results_val.box.p[1])
print("Test (sharp precision):", results_test.box.p[1])
# Out:
# Best
# Val (sharp precision): 0.4064748201438849
# Test (sharp precision): 0.37538461538461537
# Last
# Val (sharp precision): 0.22125813449023862
# Test (sharp precision): 0.21157684630738524

# %%
# 8
# seg; train s; mech_aug; full
# conf:0.1

print("Best")
print("Val (sharp precision):", results_val_2.box.p[1])
print("Test (sharp precision):", results_test_2.box.p[1])

print("Last")
print("Val (sharp precision):", results_val.box.p[1])
print("Test (sharp precision):", results_test.box.p[1])
# Out:
# Best
# Val (sharp precision): 0.46737284731581413
# Test (sharp precision): 0.4102687520576321
# Last
# Val (sharp precision): 0.4730457684921655
# Test (sharp precision): 0.413329603368269

# %%
# 8
# seg; train x; no_aug; full

print("Best")
print("Val (sharp precision):", results_val_2.box.p[1])
print("Test (sharp precision):", results_test_2.box.p[1])

print("Last")
print("Val (sharp precision):", results_val.box.p[1])
print("Test (sharp precision):", results_test.box.p[1])
# Out:
# Best
# Val (sharp precision): 0.34411764705882353
# Test (sharp precision): 0.39635793346903064
# Last
# Val (sharp precision): 0.28807947019867547
# Test (sharp precision): 0.29393939393939394

# %%
# 8
# train x; default; full

print("Best")
print("Val (sharp precision):", results_val_2.box.p[1])
print("Test (sharp precision):", results_test_2.box.p[1])

print("Last")
print("Val (sharp precision):", results_val.box.p[1])
print("Test (sharp precision):", results_test.box.p[1])
# Out:
# Best
# Val (sharp precision): 0.44553686483299887
# Test (sharp precision): 0.4149070287565503
# Last
# Val (sharp precision): 0.41784892779211946
# Test (sharp precision): 0.399046320856896

# %%
# 8
# train s; no_aug

print("Best")
print("Val (sharp precision):", results_val_2.box.p[1])
print("Test (sharp precision):", results_test_2.box.p[1])

print("Last")
print("Val (sharp precision):", results_val.box.p[1])
print("Test (sharp precision):", results_test.box.p[1])
# Out:
# Best
# Val (sharp precision): 0.42659661255108616
# Test (sharp precision): 0.4323440552627188
# Last
# Val (sharp precision): 0.4010128314716118
# Test (sharp precision): 0.41706826278673786

# %%
# 8
# train x; no_aug

print("Best")
print("Val (sharp precision):", results_val_2.box.p[1])
print("Test (sharp precision):", results_test_2.box.p[1])

print("Last")
print("Val (sharp precision):", results_val.box.p[1])
print("Test (sharp precision):", results_test.box.p[1])
# Out:
# Best
# Train (sharp precision): 0.8940836687401175
# Val (sharp precision): 0.3134762638983499
# Test (sharp precision): 0.324408297456199
# Last
# Train (sharp precision): 0.43784698916724024
# Val (sharp precision): 0.1560811253473282
# Test (sharp precision): 0.1844579961175821

# %%
# 8
# train s; no_aug

print("Best")
print("Val (sharp precision):", results_val_2.box.p[1])
print("Test (sharp precision):", results_test_2.box.p[1])

print("Last")
print("Val (sharp precision):", results_val.box.p[1])
print("Test (sharp precision):", results_test.box.p[1])
# Out:
# Best
# Train (sharp precision): 0.8535421855641424
# Val (sharp precision): 0.42035905120767053
# Test (sharp precision): 0.39148685453796955
# Last
# Train (sharp precision): 0.8731737789283975
# Val (sharp precision): 0.40731178390528927
# Test (sharp precision): 0.4538471152482169

# %%
# model = YOLO('/home/martinson/runs/segment/seg; train x; default/weights/last.pt')

# params = {
#     "conf":0.25,
# }

print("Best")
print("Val (sharp precision):", results_val_2.box.p[1])
print("Test (sharp precision):", results_test_2.box.p[1])

print("Last")
print("Val (sharp precision):", results_val.box.p[1])
print("Test (sharp precision):", results_test.box.p[1])
# Out:
# Best
# Train (sharp precision): 0.5368823938761308
# Val (sharp precision): 0.48286604361370716
# Test (sharp precision): 0.45016077170418006
# Last
# Train (sharp precision): 0.5248730964467005
# Val (sharp precision): 0.4691358024691358
# Test (sharp precision): 0.44871794871794873

# %%
# 8
# seg; train s; default

print("Best")
print("Val (sharp precision):", results_val_2.box.p[1])
print("Test (sharp precision):", results_test_2.box.p[1])

print("Last")
print("Val (sharp precision):", results_val.box.p[1])
print("Test (sharp precision):", results_test.box.p[1])
# Out:
# Best
# Train (sharp precision): 0.4454213434460976
# Val (sharp precision): 0.3627194403373844
# Test (sharp precision): 0.37144789949800194
# Last
# Train (sharp precision): 0.4490668769991456
# Val (sharp precision): 0.3984490714036438
# Test (sharp precision): 0.38625499562741583

# %%
# 8
# seg; train x; default

print("Best")
print("Val (sharp precision):", results_val_2.box.p[1])
print("Test (sharp precision):", results_test_2.box.p[1])

print("Last")
print("Val (sharp precision):", results_val.box.p[1])
print("Test (sharp precision):", results_test.box.p[1])
# Out:
# Best
# Train (sharp precision): 0.47683820912422475
# Val (sharp precision): 0.4264961309493469
# Test (sharp precision): 0.38397207821317814
# Last
# Train (sharp precision): 0.48048054743656354
# Val (sharp precision): 0.42631266490517045
# Test (sharp precision): 0.40787759667030316

# %% [markdown]
# ## Prediction

# %%
model = YOLO('/home/martinson/runs/segment/seg; train s; mech_aug; full/weights/last.pt')

model.predict(
    # source="/home/martinson/few_images_for_test",
    source='/home/martinson/few_images_for_test',
    save=True,
    iou=0.1,
    conf=0.1,
    boxes=False,
    retina_masks=True
)
# Out:
# image 1/11 /home/martinson/few_images_for_test/33349.png: 576x640 16 BLURRYs, 3 SHARP_0s, 149.6ms
# image 2/11 /home/martinson/few_images_for_test/33350.png: 576x640 16 BLURRYs, 3 SHARP_0s, 6.0ms
# image 3/11 /home/martinson/few_images_for_test/33351.png: 576x640 21 BLURRYs, 4 SHARP_0s, 6.3ms
# image 4/11 /home/martinson/few_images_for_test/33352.png: 576x640 23 BLURRYs, 16 SHARP_0s, 6.0ms
# image 5/11 /home/martinson/few_images_for_test/33353.png: 576x640 19 BLURRYs, 27 SHARP_0s, 6.3ms
# image 6/11 /home/martinson/few_images_for_test/33354.png: 576x640 17 BLURRYs, 37 SHARP_0s, 6.2ms
# image 7/11 /home/martinson/few_images_for_test/33355.png: 576x640 31 BLURRYs, 18 SHARP_0s, 6.2ms
# image 8/11 /home/martinson/few_images_for_test/33356.png: 576x640 18 BLURRYs, 4 SHARP_0s, 6.3ms
# image 9/11 /home/martinson/few_images_for_test/33357.png: 576x640 6 BLURRYs, 6.0ms
# image 10/11 /home/martinson/few_images_for_test/33358.png: 576x640 7 BLURRYs, 6.3ms
# ...

# %% [markdown]
# ## Calculate results for YOLOv5
#
# You need to change YOLOv5 code a bit to make model return precision

# %%
import yolov5.segment.val as val

folder_name = "/home/martinson/yolov5/runs/train-seg/seg; train s; no_aug/weights/"

# evaluate precision (SHARP) -- need to change YOLOv5 code for it!
_, p_train = val.run(
    data="...",
    weights=folder_name + "best",
    iou_thres=0.1,
    task='train'
)

_, p_val = val.run(
    data="...",
    weights=folder_name + "best",
    iou_thres=0.1,
    task='val'
)
_, p_test = val.run(
    data="...",
    weights=folder_name + "best",
    iou_thres=0.1,
    task='test'
)

# %%
# 5
# seg; train s; default

print("Best")
print("Train (sharp precision):", p_train)
print("Val (sharp precision):", p_val)
print("Test (sharp precision):", p_test)
# Out:
# Best
# Train (sharp precision): 0.4587575130773751
# Val (sharp precision): 0.4343376464588584
# Test (sharp precision): 0.38469494941256827

# %% [markdown]
# ## Make a graphic

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set_theme(style="whitegrid")
plt.figure(figsize=(8, 8))
plt.title("5 vs 8", fontsize=15)

# params
# iou = 0.1
# conf = 0.1

# Results - [val, test]
s8_mech = [0.48445092037864707, 0.4358943200574002]
s8_no = [0.4064748201438849,  0.37538461538461537]
x8_def = [0.44553686483299887, 0.4149]
x8_no_aug = [0.34411764705882353, 0.39635793346903064]
s5_def = [0.4343376464588584, 0.38469494941256827]

params = {
    "s":100, 
}
plt.scatter(s5_def[0], s5_def[1], label="5s", **params)
plt.scatter(x8_def[0], x8_def[1], label="8x", **params)
plt.scatter(s8_mech[0], s8_mech[1], label="8s mech", **params)
plt.scatter(s8_no[0], s8_no[1], label="8s no_aug", **params)
plt.scatter(x8_no_aug[0], x8_no_aug[1], label="8x no_aug", **params)

plt.xlabel("Val")
plt.ylabel("Test")

plt.legend(fontsize=14)
plt.savefig("segmentation results_2.png")
